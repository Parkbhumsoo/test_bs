# %%
list = [ 'abcd', 786 , 2.23, 'john', 70.2 ]

# %%
tinylist = [123, 'john']

print(list);     print(list[0]);             print(list[1:3]);     print(list[2:])
# Out:
# ['abcd', 786, 2.23, 'john', 70.2]
# abcd
# [786, 2.23]
# [2.23, 'john', 70.2]

# %%
print(tinylist * 2);      print(list + tinylist);
# Out:
# [123, 'john', 123, 'john']
# ['abcd', 786, 2.23, 'john', 70.2, 123, 'john']

# %%
age=int(input("What is your age?"))

print("나이는",age,"살 입니다.")
# Out:
# What is your age?13
# 나이는 13 살 입니다.

# %%
movies = ["The Holy Grail", "The Life of Brian", "The Meaning of Life"]

# %%
for i in movies:
  print(i)
# Out:
# The Holy Grail
# The Life of Brian
# The Meaning of Life

# %%
movies[1]
# Out:
# 'The Life of Brian'

# %%
len(movies)
# Out:
# 3

# %%
score = input("What is your score?")

 if score >=90:

    scoreb="A"

 elif score>=80:

    scoreb="B"

 elif score>=60:

    scoreb="C"

 else:

    scoreb="D"

print("your score is",scoreb)
# Out:
#   File "<ipython-input-9-0b0f4c4c1ec1>", line 3
#     if score >=90:
#     ^
# IndentationError: unexpected indent

# %%
dict = {}

dict['one'] = "This is one"

dict[2]     = "This is two"

tinydict = {'name': 'john','code':6734, 'dept': 'sales'}

# %%
print(tinydict.values());
# Out:
# dict_values(['john', 6734, 'sales'])

# %%
movies = ['The Holy Grail', 1975, 'The Life of Brian', 91, 

                     ['Graham Cahpman',['Michael Palin', 'John Cleese', 'Terry Gilliam', 'Eric Idle']]]

for each_item in movies:

  print(each_item)
# Out:
# The Holy Grail
# 1975
# The Life of Brian
# 91
# ['Graham Cahpman', ['Michael Palin', 'John Cleese', 'Terry Gilliam', 'Eric Idle']]

# %%
리스트란 변수란 함수란
