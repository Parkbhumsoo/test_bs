# %%
students_score=[
               {'num':'1','name':'김철수','kor':90,'eng':80,'math':85},
               {'num':'2','name':'박제동','kor':90,'eng':85,'math':90},
               {'num':'3','name':'홍길동','kor':80,'eng':80,'math':80},
               {'num':'4','name':'박범수','kor':80,'eng':90,'math':95},
               {'num':'5','name':'정희정','kor':90,'eng':85,'math':75}
]

# %%
for i in range(len(students_score)):
  students_score[i]['total']= students_score[i]['kor']+students_score[i]['eng']+students_score[i]['math']
for i in range(len(students_score)):
  a= students_score[i]['avg']=students_score[i]['total']/3

# %%
students_score
# Out:
# [{'avg': 85.0,
#   'eng': 80,
#   'kor': 90,
#   'math': 85,
#   'name': '김철수',
#   'num': '1',
#   'total': 255},
#  {'avg': 88.33333333333333,
#   'eng': 85,
#   'kor': 90,
#   'math': 90,
#   'name': '박제동',
#   'num': '2',
#   'total': 265},
#  {'avg': 80.0,
#   'eng': 80,
#   'kor': 80,
#   'math': 80,
#   'name': '홍길동',
#   'num': '3',
#   'total': 240},
#  {'avg': 88.33333333333333,
#   'eng': 90,
#   'kor': 80,
#   'math': 95,
#   'name': '박범수',
#   'num': '4',
#   'total': 265},
#  {'avg': 83.33333333333333,
#   'eng': 85,
#   'kor': 90,
#   'math': 75,
#   'name': '정희정',
#   'num': '5',
#   'total': 250}]

# %%
for i in range(len(students_score)):
  a= students_score[i]['avg']=students_score[i]['total']/3
  print(students_score[i]['name'],"의 평균점수는 ",a,"점 입니다.")
# Out:
# 김철수 의 평균점수는  85.0 점 입니다.
# 박제동 의 평균점수는  88.33333333333333 점 입니다.
# 홍길동 의 평균점수는  80.0 점 입니다.
# 박범수 의 평균점수는  88.33333333333333 점 입니다.
# 정희정 의 평균점수는  83.33333333333333 점 입니다.

# %%
b=(students_score[0]['kor']+students_score[1]['kor']+students_score[2]['kor']+students_score[3]['kor']+students_score[4]['kor'])/5
c=(students_score[0]['eng']+students_score[1]['eng']+students_score[2]['eng']+students_score[3]['eng']+students_score[4]['eng'])/5
d=(students_score[0]['math']+students_score[1]['math']+students_score[2]['math']+students_score[3]['math']+students_score[4]['math'])/5

# %%
print("국어 평균은",b,"점 입니다.")
print("영어 평균은",c,"점 입니다.")
print("수학 평균은",d,"점 입니다.")
# Out:
# 국어 평균은 18.0 점 입니다.
# 영어 평균은 84.0 점 입니다.
# 수학 평균은 85.0 점 입니다.

# %%
for i in range(len(students_score)):
  b=students_score[i]['kor']/5
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-adc7afd5afe8> in <module>()
#       1 for i in range(len(students_score[i])):
# ----> 2   b=students_score[i]['kor']/5
#
# IndexError: list index out of range

# %%
sum(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-bcf8a5bf121a> in <module>()
# ----> 1 sum(b)
#
# TypeError: 'float' object is not iterable
