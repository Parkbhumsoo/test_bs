# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
info_url = "http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109"
response = requests.get(info_url)
soup = BeautifulSoup(response.content,'html.parser')
soup

# %%
locations = soup.find_all('location')

# %%
for location in locations:
  print(location.find('city').text,":",location.find('wf').text)
# Out:
# 서울 : 구름많음
# 인천 : 구름많음
# 수원 : 구름많음
# 파주 : 구름많음
# 이천 : 구름많음
# 평택 : 구름많음
# 백령도 : 구름많음
# 과천 : 구름많음
# 광명 : 구름많음
# 강화 : 구름많음
# 김포 : 구름많음
# 시흥 : 구름많음
# 안산 : 구름많음
# 부천 : 구름많음
# 의정부 : 구름많음
# 고양 : 구름많음
# 양주 : 구름많음
# 동두천 : 구름많음
# 연천 : 구름많음
# 포천 : 구름많음
# 가평 : 구름많음
# 구리 : 구름많음
# 남양주 : 구름많음
# 양평 : 구름많음
# 하남 : 구름많음
# 안양 : 구름많음
# 오산 : 구름많음
# 화성 : 구름많음
# 성남 : 구름많음
# 의왕 : 구름많음
# 군포 : 구름많음
# 안성 : 구름많음
# 용인 : 구름많음
# 광주 : 구름많음
# 여주 : 구름많음

# %%
url='http://finance.daum.net/api/market_index/days?page=1&perPage=100&market=KOSPI&pagination=true'
header = {'Referer':'http://finance.daum.net/domestic/kospi',
'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}

# %%
r3=requests.get(url,headers = header)
import json
rt_dict = json.loads(r3.content)
rt_dict

# %%
rt_dict.keys()

# %%
wpi=pd.DataFrame(rt_dict['data'])
wpi

# %%
wpi.loc[0:10]

# %%
url='https://openapi.naver.com/v1/search/news.json?query=스마트'
header = {'X-Naver-Client-Id' :'3U2AUwPQfUF5XD3WIoAs', 'X-Naver-Client-Secret' : 'YSNxUasBmn'}
r3 = requests.get(url, headers = header)

# %%
r3.status_code
# Out:
# 200

# %%
soup_news = BeautifulSoup(r3.content, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-51ee6330f532> in <module>()
# ----> 1 soup_news = BeautifulSoup(r3.content, 'html.parser')
#
# NameError: name 'BeautifulSoup' is not defined

# %%
soup_news

# %%
snw = soup_news.find_all('title')
snw

# %%
url = "http://www.jobkorea.co.kr/Salary/?act=c&el=tab_part"  # 부부의 세계 기사
res= requests.get(url)
soup=BeautifulSoup(res.text, 'html.parser')
soup

# %%
job = soup.find('ol',{'class':"list hover"})
b=job.text
print(b)
# Out:
# 1
# 카카오
# 8,579
#
#
#
#
# 2
# 셀트리온헬스케어
# 24,081
#
#
#
#
# 3
# JYP Ent.
# 7,696
#
#
#
#
# 4
# 삼성전자
# 11,157
#
#
#
#
# 5
# 아프리카TV
# 3,935
#
#
#
#
# 6
# 호텔신라
# 5,276
#
#
#
#
# 7
# SK하이닉스
# 10,196
#
#
#
#
# 8
# NAVER
# 7,157
#
#
#
#
# 9
# 공무원연금공단
# 7,051
#
#
#
#
# 10
# 도쿄일렉트론코리아
# 5,042
