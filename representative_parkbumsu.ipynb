# %%
import numpy as np

student_score = [
 [1, 90, 80, 85, 0, 0.0, 0],
 [2, 90, 85, 90, 0, 0.0, 0],
 [3, 80, 80, 80, 0, 0.0, 0]
]

# %%
a = [
{'num':'1', 'name':'김철수','kor':90, 'eng':80, 'math':85, 'total':0, 'avg':0.0, 'order':0 },
{'num':'2', 'name':'박제동','kor':90, 'eng':85, 'math':90, 'total':0, 'avg':0.0, 'order':0 },
{'num':'3', 'name':'홍길동','kor':80,' eng':80, 'math':80, 'total':0, 'avg':0.0, 'order':0 }
]

# %%
student_scores_high = np.random.randint(low = 80, high=100, size =(30, 3))
student_scores_middle = np.random.randint(low = 50, high=79, size =(20, 3)) 
student_scores_low = np.random.randint(low = 0, high=49, size =(100, 3)) 
student_scores_high

# %%
st=np.insert(student_scores_high,0,student_scores_low,axis=0)
student = np.insert(st,100,student_scores_middle,axis=0)

# %%
for i in range(0,3):
  if i== 0:
      print('국어')
  elif i==1:
      print('영어')
  else:
      print('수학')
  print("표준편차:",np.std(student[:,i]))
  print("평균:",student[:,i].mean())
  print("중간값:",np.median(student[:,i]))
  print("분산:",np.var(student[:,i]))
  print("최대값:",np.max(student[:,i]))
  print("최소값:",np.min(student[:,i]))
  print("\n")
# Out:
# 국어
# 표준편차: 30.26497792645633
# 평균: 41.46666666666667
# 중간값: 34.5
# 분산: 915.9688888888887
# 최대값: 99
# 최소값: 0
#
#
# 영어
# 표준편차: 29.84256840301935
# 평균: 41.96666666666667
# 중간값: 36.0
# 분산: 890.5788888888887
# 최대값: 99
# 최소값: 0
#
#
# 수학
# 표준편차: 30.24527070469035
# 평균: 41.94
# 중간값: 34.0
# 분산: 914.7764000000002
# 최대값: 99
# 최소값: 0

# %% [markdown]
# 평균

# %%
sth=student_scores_high

# %%
for i in range(0,3):
  if i== 0:
      print('국어')
  elif i==1:
      print('영어')
  else:
      print('수학')
  print("표준편차:",np.std(sth[:,i]))
  print("평균:",np.mean(sth[:,i]))
  print("중간값:",np.median(sth[:,i]))
  print("표준편차:",np.std(sth[:,i]))
  print("분산:",np.var(sth[:,i]))
  print("최대값:",np.max(sth[:,i]))
  print("최소값:",np.min(sth[:,i]))
  print("\n")

# %%
stl=student_scores_low

# %%
for i in range(0,3):
  if i== 0:
      print('국어')
  elif i==1:
      print('영어')
  else:
      print('수학')
  print("표준편차:",np.std(stl[:,i]))
  print("평균:",np.mean(stl[:,i]))
  print("중간값:",np.median(stl[:,i]))
  print("표준편차:",np.std(stl[:,i]))
  print("분산:",np.var(stl[:,i]))
  print("최대값:",np.max(stl[:,i]))
  print("최소값:",np.min(stl[:,i]))
  print("\n")

# %%
student
