# %%
os.mkdir("newdir")  # 폴더 만들기

# %%
import os

# %%
os.mkdir("./dir01")

# %%
os.getcwd()  # 현재 위치
# Out:
# '/content/dir01'

# %%
os.chdir('../')
print(os.getcwd())
# Out:
# /

# %%
os.chdir("dir01")

# %%
os.mkdir("./dir02")

# %%
os.rmdir("./dir02")

# %%
os.mkdir("./dir03")

# %%
os.chdir("../")

# %%
os.getcwd()
# Out:
# '/content/dir01'

# %%
os.rmdir("dir02")

# %%
os.rmdir("dir03")

# %%
os.getcwd()
# Out:
# '/content/dir01'
