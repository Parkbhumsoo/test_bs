# %%
animals=['tiger','lion','horse']

# %%
animals
# Out:
# ['tiger', 'lion', 'horse']

# %%
animals[1]
# Out:
# 'lion'

# %%
len(animals[2])
# Out:
# 5

# %%
animals[2]
# Out:
# 'horse'

# %%
del animals[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-21af384a403e> in <module>()
# ----> 1 del animals[2]
#
# IndexError: list assignment index out of range

# %%
animals
# Out:
# ['tiger', 'lion']
