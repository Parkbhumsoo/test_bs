# %%
b= '20011042rainy'

# %%
print(b[:-1]) # print(b[0:8])
# Out:
# 20011042rain

# %%
a='this is a string'

# %%
a= a.replace('string','rope')

# %%
a
# Out:
# 'this is a rope'

# %%
a
# Out:
# 'this is a string'

# %%
c[10:]
# Out:
# 'rope'

# %%
c,a
# Out:
# ('this is a rope', 'this is a string')

# %%
a.count('ul')
# Out:
# 0

# %%
a="korean culture"

# %%
a.count('e')
# Out:
# 2

# %%
a.find('c')
# Out:
# 7

# %%
b='       korean food        '

# %%
b.strip()
# Out:
# 'korean food'

# %%
c = "korean & American & china"

# %%
c.split("&")
# Out:
# ['korean ', ' American ', ' china']
