# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
df1 = pd.DataFrame(np.random.randn(100,3))

# %%
df1.tail()
# Out:
#            0         1         2
# 95 -0.771625 -1.168258  0.751253
# 96  0.536427  1.171372  0.745380
# 97  0.374995 -0.327216  1.236970
# 98  0.419955  0.671616  0.822542
# 99 -0.051361 -0.418113  1.441838

# %%
df1.plot()

# %%
obj1 = pd.Series([4, 5, -2], index=["a", "b", "c"])

# %%
obj1
# Out:
# a    4
# b    5
# c   -2
# dtype: int64

# %%
obj1.values
# Out:
# array([ 4,  5, -2])

# %%
obj1.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
obj1.dtypes
# Out:
# dtype('int64')

# %%
obj1.shape
# Out:
# (3,)

# %%
type(obj1)
# Out:
# pandas.core.series.Series

# %%
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}

# %%
df01 = pd.DataFrame(data, index=['rank1','rank2','rank3','rank4'])

# %%
df01
# Out:
#         Name  Age
# rank1    Tom   28
# rank2   Jack   34
# rank3  Steve   29
# rank4  Ricky   42

# %%
df01.values, df01.index, df01.columns, df01.dtypes
# Out:
# (array([['Tom', 28],
#         ['Jack', 34],
#         ['Steve', 29],
#         ['Ricky', 42]], dtype=object),
#  Index(['rank1', 'rank2', 'rank3', 'rank4'], dtype='object'),
#  Index(['Name', 'Age'], dtype='object'),
#  Name    object
#  Age      int64
#  dtype: object)

# %%
obj1.DataFrame.info
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-98b6a8279d54> in <module>()
# ----> 1 obj1.DataFrame.info
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'DataFrame'
