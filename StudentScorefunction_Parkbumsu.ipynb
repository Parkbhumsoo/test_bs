# %%
students_score = [
                  {'num':1, 'name':'김철수','kor':90,'eng':80,'math':85},
                  {'num':2, 'name':'박제동','kor':90,'eng':85,'math':90},
                  {'num':3, 'name':'홍길동','kor':80,'eng':80,'math':80}
]

# %%
students_score.append({'num':4, 'name':'김누누','kor':70,'eng':90,'math':85})
students_score.append({'num':5, 'name':'김쿵야','kor':95,'eng':75,'math':85})
students_score
# Out:
# [{'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': 1},
#  {'eng': 85, 'kor': 90, 'math': 90, 'name': '박제동', 'num': 2},
#  {'eng': 80, 'kor': 80, 'math': 80, 'name': '홍길동', 'num': 3},
#  {'eng': 90, 'kor': 70, 'math': 85, 'name': '김누누', 'num': 4},
#  {'eng': 75, 'kor': 95, 'math': 85, 'name': '김쿵야', 'num': 5}]

# %%
for i in range(len(students_score)):
  students_score[i]['total']=students_score[i]['kor']+students_score[i]['eng']+students_score[i]['math']

# %%
students_score
# Out:
# [{'eng': 80, 'kor': 90, 'math': 85, 'name': '김철수', 'num': 1, 'total': 255},
#  {'eng': 85, 'kor': 90, 'math': 90, 'name': '박제동', 'num': 2, 'total': 265},
#  {'eng': 80, 'kor': 80, 'math': 80, 'name': '홍길동', 'num': 3, 'total': 240},
#  {'eng': 90, 'kor': 70, 'math': 85, 'name': '김누누', 'num': 4, 'total': 245},
#  {'eng': 75, 'kor': 95, 'math': 85, 'name': '김쿵야', 'num': 5, 'total': 255}]

# %%
for i in range(len(students_score)):
  a=students_score[i]['avg']=students_score[i]['total']/3

# %%
students_score
# Out:
# [{'avg': 85.0,
#   'eng': 80,
#   'kor': 90,
#   'math': 85,
#   'name': '김철수',
#   'num': 1,
#   'total': 255},
#  {'avg': 88.33333333333333,
#   'eng': 85,
#   'kor': 90,
#   'math': 90,
#   'name': '박제동',
#   'num': 2,
#   'total': 265},
#  {'avg': 80.0,
#   'eng': 80,
#   'kor': 80,
#   'math': 80,
#   'name': '홍길동',
#   'num': 3,
#   'total': 240},
#  {'avg': 81.66666666666667,
#   'eng': 90,
#   'kor': 70,
#   'math': 85,
#   'name': '김누누',
#   'num': 4,
#   'total': 245},
#  {'avg': 85.0,
#   'eng': 75,
#   'kor': 95,
#   'math': 85,
#   'name': '김쿵야',
#   'num': 5,
#   'total': 255}]

# %%
def stu_avg(a_score):
  a_score=students_score[0]['total']+students_score[1]['total']+students_score[2]['total']+students_score[3]['total']+students_score[4]['total']
  print("학급 평균점수는:",a_score/5)
  return;
stu_avg(students_score)
# Out:
# 학급 평균점수는: 252.0

# %%
def kor_avg(k_score):
  k_score=students_score[0]['kor']+students_score[1]['kor']+students_score[2]['kor']+students_score[3]['kor']+students_score[4]['kor']
  print("국어 평균점수는:",k_score/5)
  return;

def eng_avg(e_score):
  e_score=students_score[0]['eng']+students_score[1]['eng']+students_score[2]['eng']+students_score[3]['eng']+students_score[4]['eng']
  print("영어 평균점수는:",e_score/5)
  return;

def mat_avg(k_score):
  m_score=students_score[0]['math']+students_score[1]['math']+students_score[2]['math']+students_score[3]['math']+students_score[4]['math']
  print("수학 평균점수는:",m_score/5)
  return;

# %%
kor_avg(students_score)
eng_avg(students_score)
mat_avg(students_score)
# Out:
# 국어 평균점수는: 85.0
# 영어 평균점수는: 82.0
# 수학 평균점수는: 85.0
